# %% [markdown]
# <a href="https://colab.research.google.com/github/MigMo-24/TACO/blob/master/yolor_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linking google drive to google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Checking directory
# %cd /content
# !pwd
# Out:
# /content
# /content

# %%
#clonning yolor
# !git clone https://github.com/augmentedstartups/yolor
# %cd yolor
# Out:
# Cloning into 'yolor'...
# remote: Enumerating objects: 375, done.
# remote: Total 375 (delta 0), reused 0 (delta 0), pack-reused 375
# Receiving objects: 100% (375/375), 2.97 MiB | 14.00 MiB/s, done.
# Resolving deltas: 100% (163/163), done.
# /content/yolor

# %%
#checking directory
# !pwd
# Out:
# /content/yolor

# %%
#installing requierements
# !pip install -qr requirements.txt

# %%
# %cd /content/yolor/
# Out:
# /content/yolor

# %%
#check python verison
# !python --version

# %%
#cloning mish-cuda
# !git clone https://github.com/JunnYu/mish-cuda
# %cd mish-cuda
#installing cuda
# !python setup.py build install
# Out:
# Cloning into 'mish-cuda'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 195 (delta 7), reused 79 (delta 3), pack-reused 107
# Receiving objects: 100% (195/195), 208.77 KiB | 3.16 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# /content/yolor/mish-cuda
# /usr/lib/python3.7/distutils/extension.py:131: UserWarning: Unknown Extension options: 'headers'
#   warnings.warn(msg)
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/mish_cuda
# copying src/mish_cuda/__init__.py -> build/lib.linux-x86_64-3.7/mish_cuda
# running egg_info
# creating src/mish_cuda.egg-info
# writing src/mish_cuda.egg-info/PKG-INFO
# writing dependency_links to src/mish_cuda.egg-info/dependency_links.txt
# writing requirements to src/mish_cuda.egg-info/requires.txt
# ...

# %%
# %cd /content/yolor
# !pwd
# Out:
# /content/yolor
# /content/yolor

# %%
#install PyTorch Wavelets
#cloning pytorch
# !git clone https://github.com/fbcotter/pytorch_wavelets
# %cd pytorch_wavelets
# !pip install .
# Out:
# Cloning into 'pytorch_wavelets'...
# remote: Enumerating objects: 972, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 972 (delta 75), reused 89 (delta 45), pack-reused 836
# Receiving objects: 100% (972/972), 6.80 MiB | 22.17 MiB/s, done.
# Resolving deltas: 100% (659/659), done.
# /content/yolor/pytorch_wavelets
# Processing /content/yolor/pytorch_wavelets
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...

# %%
# %cd /content/yolor

# %%
#download the pre-trained models using the bash 
#script provided in the scripts sub-directory.
# !bash scripts/get_pretrain.sh

# %%
# %cd /content/yolor/
# Out:
# /content/yolor

# %%
# !curl -L "https://app.roboflow.com/ds/TyliD2kPdq?key=94EhoEQ7av" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: test/images/johnson_y50_jpg.rf.747e454c4df8945e4646df63b047dca6.jpg
#  extracting: test/images/johnson_y59_jpg.rf.de5549f18ce2166cefd604cb7de705d2.jpg
#  extracting: test/images/johnson_y70_jpg.rf.40e15e2817a8fbd3f5a9b37d59d46cfa.jpg
#  extracting: test/images/johnson_y78_jpg.rf.d15cf22d2405f29f2a4c26c7e523ed5c.jpg
#  extracting: test/images/johnson_y93_jpg.rf.4570566ec21650dc016f35f83c7993f7.jpg
#  extracting: test/images/johnson_y96_jpg.rf.ed6874ed33702bcf97c45d79c24a3747.jpg
#  extracting: test/images/kiefer_y109_jpg.rf.a4b003ccceffc4931b40dd1dc5f64f86.jpg
#  extracting: test/images/kiefer_y120_jpg.rf.ce2cb36fc8af9ebe665279c728ad5ca5.jpg
#  extracting: test/images/kiefer_y12_jpg.rf.22a26596379ee9b6ba67e4149a0916e4.jpg
#  extracting: test/images/kiefer_y131_jpg.rf.691dbec9bedddecad983e42ea6583896.jpg
#  extracting: test/images/kiefer_y136_jpg.rf.bab0ca17009633a153b254f5f699ae6f.jpg
# ...

# %%
# !pip install wandb

# %%
#running command line
# !python detect.py --source inference/images/horses.jpg --cfg cfg/yolor_p6.cfg --weights yolor_p6.pt --conf 0.25 --img-size 1280 --device 0 --output /content/drive/MyDrive/yolor/yolor_output_image
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolor_p6.cfg', classes=None, conf_thres=0.25, device='0', img_size=1280, iou_thres=0.5, names='data/coco.names', output='/content/drive/MyDrive/yolor/yolor_output_image', save_txt=False, source='inference/images/horses.jpg', update=False, view_img=False, weights=['yolor_p6.pt'])
# Traceback (most recent call last):
#   File "detect.py", line 186, in <module>
#     detect()
#   File "detect.py", line 44, in detect
#     model.load_state_dict(torch.load(weights[0], map_location=device)['model'])
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 595, in load
#     return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 764, in _legacy_load
#     magic_number = pickle_module.load(f, **pickle_load_args)
# _pickle.UnpicklingError: invalid load key, '\x00'.

# %%
#to show image in screen
import glob
from IPython.display import Image, display
for imageName in glob.glob('/content/drive/MyDrive/yolor/yolor_output_image/*.jpg'):
  display(Image(filename=imageName))
  print("/n")

# %%
# !python train.py --batch-size 8 --img 416 416 --data 'data.yaml' --cfg cfg/yolor_p6.cfg --weights 'yolor_p6.pt' --device 0 --name yolor_p6 --hyp 'data/hyp.scratch.1280.yaml' --epochs 5
# Out:
# Using torch 1.7.0 CUDA:0 (Tesla K80, 11441MB)
#
# Namespace(adam=False, batch_size=8, bucket='', cache_images=False, cfg='cfg/yolor_p6.cfg', data='data.yaml', device='0', epochs=5, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.1280.yaml', image_weights=False, img_size=[416, 416], local_rank=-1, log_imgs=16, multi_scale=False, name='yolor_p6', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/yolor_p612', single_cls=False, sync_bn=False, total_batch_size=8, weights='yolor_p6.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# NumExpr defaulting to 2 threads.
# ...
